# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# ### Importing the dataset

# %%
df_red = pd.read_csv("wine+quality//winequality-red.csv", sep=';')
df_red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df_white=pd.read_csv("wine+quality//winequality-white.csv", sep=";")
df_white
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# #### Exploratory Data Analysis (EDA)/ Explore the dataset's structure and summary statistics

# %%
df_red.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df_white.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
df_red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df_white.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %% [markdown]
# ### Visualize key features using plots

# %%
df_red.hist(bins=10, color = 'orange', edgecolor = 'black', figsize =(15,10))
plt.show()

df_white.hist(bins=10, color = 'skyblue', edgecolor = 'black', figsize =(15,10))
plt.show()

# %% [markdown]
# ### Hypothesis Formulation

# %% [markdown]
# #### 1. Null: There is no correlation between the quality of red wines and its fixed acidicity./ Alt: There is a significant correlation.
# #### 2. Null: The density of red wine is the same as the density of white wine. / Alt: There is difference between them.

# %% [markdown]
# ### Hypothesis Testing/Test the formulated hypotheses using statistical tests or visualizations

# %%
# 1st Hypothesis/Pearson 
alpha=0.05
cor_coef, pvalue =  stats.pearsonr(df_red["quality"], df_red["fixed acidity"])
print(f"Correlation Coefficient: {cor_coef}")
print(f"P-value: {pvalue}")
alpha = 0.05
if pvalue > alpha:
    print("Fail to reject the null hypothesis. There is no significant correlation.")
else:
    print("Reject the null hypothesis. There is a significant correlation.")
# Out:
# Correlation Coefficient: 0.12405164911322429
# P-value: 6.495635009279656e-07
# Reject the null hypothesis. There is a significant correlation.

# %%
#2nd Hypothesis 
alpha=0.05
t_stat, pvalue =stats.ttest_ind(df_red["density"], df_white["density"])
print(f"T-statistic: {t_stat}")
print(f"P-value: {pvalue}")
if pvalue < 0.05:
    print("Reject the null hypothesis")
else:
    print("Fail to reject the null hypothesis")
# Out:
# T-statistic: 34.200222895156706
# P-value: 7.319604639974869e-236
# Reject the null hypothesis

# %% [markdown]
# ### Documentation and Reporting

# %% [markdown]
# Through out the EDA and analyzing process, first I figured out the distriubtion of red wines and white wines using histogram in pyplot library. Also, I obtained basic statisticus using .describe and figured out the data types and structure of each data sets using .info().
#
# After that, employing imported library of scipy.stats, I conducted hypothesis test on two formulated hypothesis. For the first hypothesis, the p-value is less than alpha(significance level), so we rejected the null hypothesis and found out that there is a significant correlation between the quality of red wines and its fixed acidicity.
#
# For the second hypothesis, We also rejected the null hypothesis and found out there is a difference between densitiy of red wine and the density of white wine using T-test and its p-value since its p-value is less than the alpha.
